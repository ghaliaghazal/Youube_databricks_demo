# %% [markdown]
# # pyspark intro
#
# a short note on notebook in databricks - can choose between
# - SQL notebook
# - Python notebook
#
# the choice makes all calles default to the choice e.g. SQL by default

# %%
from pathlib import Path

print("hej")
